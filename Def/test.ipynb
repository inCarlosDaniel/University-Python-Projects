# %%
# %%writefile exemplo.py

def saudacao(nome):
    
    return f"Olá, {nome}!"

def dobro(x):
    
    return x * 2

def calcular_media(n1, n2):
    
    return (n1 + n2) / 2
# Out:
# Writing exemplo.py

# %%
# %%writefile uso.py
import exemplo 

print(exemplo.saudacao("Alice"))
print(exemplo.dobro(5))
print(exemplo.calcular_media(8, 10))
# Out:
# Writing uso.py

# %%
# !python uso.py
# Out:
# Olá, Alice!
# 10
# 9.0
